# %% [markdown]
# # **Motive**
#
# *This notebook is made to evaluate the inference time and accuracy of the GLAM SER model*

# %% [markdown]
# ## **TPU Access (Colab)**

# %%
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# Tensorflow version 2.12.0
# Running on TPU  ['10.17.137.210:8470']

# %% [markdown]
# # **Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Requirements**

# %%
# !pip install torch
# !pip install g_mlp_pytorch
# !pip install area_attention
# !pip install pytorch_model_summary

# %%
import os

# %% [markdown]
# # **Prepare project content**

# %%
# Create directories
def create_directories(directories):
    for directory in directories:
        try:
            os.makedirs(directory)
            print(f"Directory '{directory}' created")
        except FileExistsError:
            print(f"Directory '{directory}' already exists")
create_directories(['libs',  'models', 'weights', 'data', 'data/IEMOCAP', 'data/MFCC'])

# Copy data files
try:
  print('No IEMOCAP data files loaded yet')
except FileExistsError:
  pass
except Exception as e:
  print("An error occurred while copying the IEMOCAP data files:", e)

# Gathering external libraries
# !git clone https://github.com/lixiangucas01/GLAM.git libs/GLAM
# Out:
# Directory 'libs' created
# Directory 'models' created
# Directory 'weights' created
# Directory 'data' created
# Directory 'data/IEMOCAP' created
# Directory 'data/MFCC' created
# No IEMOCAP data files loaded yet
# Cloning into 'libs/GLAM'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 93 (delta 0), reused 0 (delta 0), pack-reused 92
# Unpacking objects: 100% (93/93), 6.82 MiB | 9.44 MiB/s, done.
